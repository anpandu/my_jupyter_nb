# %%
import tensorflow as tf
from tensorflow.keras import Sequential, layers, optimizers, losses

# %%
# importing Libraries
import math

from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from eli5.permutation_importance import get_score_importances
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, KBinsDiscretizer, OrdinalEncoder
# from sklearn.datasets import make_classification

# %%
from modules.ui import show_hist, show_hists, show_skew_kurt, show_corr, draw_map
from modules.utils import printh, xfrange, scale

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
coor_x = "Lattitude"
coor_y = "Longtitude"
label_altitudes = [
    "Price",
    "Distance",
]
for label_altitude in label_altitudes:
    plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
    plotted_df = plotted_df.dropna()
    draw_map(
        input_df=plotted_df,
        coor_x=coor_x,
        coor_y=coor_y,
        label=label_altitude,
        group_by="mean",
        scale_factor=300,
    )

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
coor_x = "Lattitude"
coor_y = "Longtitude"
label_altitudes = [
    "Rooms",
    "Bedroom2",
    "Bathroom",
    "Car",
    "Propertycount",
]
for label_altitude in label_altitudes:
    plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
    plotted_df = plotted_df.dropna()
    draw_map(
        input_df=plotted_df,
        coor_x=coor_x,
        coor_y=coor_y,
        label=label_altitude,
        scale_factor=300,
    )

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "Postcode"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()
# print(plotted_df.describe())

plotted_df[label_altitude] = plotted_df[label_altitude].clip(lower=0, upper=3250) 
min_ = 2999
plotted_df[label_altitude] = plotted_df[label_altitude] - min_
# print(plotted_df.describe())
# plotted_df[[label_altitude]].hist()

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "YearBuilt"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()
# print(plotted_df.describe())

min_yb = 1800
plotted_df[label_altitude] = plotted_df[label_altitude] - min_yb
plotted_df[label_altitude] = plotted_df[label_altitude].clip(lower=0) 

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "Regionname"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()
plotted_df[label_altitude] = plotted_df[label_altitude].replace({
    "Eastern Metropolitan": 1,
    "Eastern Victoria": 2,
    "Northern Metropolitan": 3,
    "Northern Victoria": 4,
    "South-Eastern Metropolitan": 5,
    "Southern Metropolitan": 6,
    "Western Metropolitan": 7,
    "Western Victoria": 0,
})
# print(plotted_df.describe())

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "Suburb"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()

enc = OrdinalEncoder(
    dtype=object,
    handle_unknown='use_encoded_value',
    unknown_value=-1
)
enc.fit(plotted_df[[label_altitude]])
# print(enc.categories_)
plotted_df[[label_altitude]]  = enc.transform(plotted_df[[label_altitude]])

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "SellerG"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()

enc = OrdinalEncoder(
    dtype=object,
    handle_unknown='use_encoded_value',
    unknown_value=-1
)
enc.fit(plotted_df[[label_altitude]])
# print(enc.categories_)
plotted_df[[label_altitude]]  = enc.transform(plotted_df[[label_altitude]])

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "Type"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()

enc = OrdinalEncoder(
    dtype=object,
    handle_unknown='use_encoded_value',
    unknown_value=-1
)
enc.fit(plotted_df[[label_altitude]])
# print(enc.categories_)
plotted_df[[label_altitude]]  = enc.transform(plotted_df[[label_altitude]])

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "Method"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()

enc = OrdinalEncoder(
    dtype=object,
    handle_unknown='use_encoded_value',
    unknown_value=-1
)
enc.fit(plotted_df[[label_altitude]])
# print(enc.categories_)
plotted_df[[label_altitude]]  = enc.transform(plotted_df[[label_altitude]])

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "Landsize"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()

# min_yb = 1800
# plotted_df[label_altitude] = plotted_df[label_altitude] - min_yb
plotted_df[label_altitude] = plotted_df[label_altitude].clip(upper=5000) 
# print(plotted_df.describe())
# plotted_df[[label_altitude]].hist()

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)

# %%
main_df = pd.read_csv('melbourne_house_prices.csv')
label_altitude = "BuildingArea"
coor_x = "Lattitude"
coor_y = "Longtitude"
plotted_df = main_df[[coor_x,coor_y,label_altitude]].copy()
plotted_df = plotted_df.dropna()

# min_yb = 1800
# plotted_df[label_altitude] = plotted_df[label_altitude] - min_yb
plotted_df[label_altitude] = plotted_df[label_altitude].clip(upper=1000) 
# print(plotted_df.describe())
# plotted_df[[label_altitude]].hist()

draw_map(
    input_df=plotted_df,
    coor_x=coor_x,
    coor_y=coor_y,
    label=label_altitude,
    scale_factor=300,
)
